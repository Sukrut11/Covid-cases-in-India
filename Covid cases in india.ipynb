# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
plt.style.use("dark_background")

# %%
df= pd.read_csv("https://raw.githubusercontent.com/ashish-ash303/Covid-19-2nd-Wave-eda/main/Latest%20Covid-19%20India%20Status.csv")

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7549       1        7419     129
# 1       Andhra Pradesh      1995669   16341     1965657   13671
# 2    Arunachal Pradesh        51655    1763       49640     252
# 3                Assam       581398    8772      567113    5513
# 4                Bihar       725518     204      715665    9649
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.01                98.28             1.71
# 1              0.82                98.50             0.69
# 2              3.41                96.10             0.49
# 3              1.51                97.54             0.95
# 4              0.03                98.64             1.33

# %%
df.shape
# Out:
# (36, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000
# mean   8.968294e+05   10205.972222  8.746090e+05   12014.416667
# std    1.303563e+06   30660.005408  1.262310e+06   23205.834381
# min    7.549000e+03       1.000000  7.419000e+03       4.000000
# 25%    6.981775e+04     213.750000  6.598125e+04     803.750000
# 50%    4.645165e+05    1062.500000  4.546995e+05    5322.500000
# 75%    9.980822e+05    7369.500000  9.826742e+05   13579.500000
# max    6.401213e+06  175695.000000  6.201168e+06  135255.000000
#
#        Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# count         36.000000            36.000000        36.000000
# mean           1.682222            97.052222         1.265000
# std            3.335660             3.239175         0.564464
# min            0.010000            81.440000         0.040000
# 25%            0.067500            97.150000         0.947500
# ...

# %%
df.isnull().sum()
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['State/UTs',
#  'Total Cases',
#  'Active',
#  'Discharged',
#  'Deaths',
#  'Active Ratio (%)',
#  'Discharge Ratio (%)',
#  'Death Ratio (%)']

# %% [markdown]
# # Which State/UTs has highest recovery rate ?

# %%
recovery= df.sort_values(by="Discharge Ratio (%)", ascending= False)

# %%
recovery.head()
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        10657       4       10649
# 18                               Lakshadweep        10295      34       10210
# 28                                 Rajasthan       953960     163      944843
# 10                                   Gujarat       825213     179      814956
# 11                                   Haryana       770245     660      759924
#
#     Deaths  Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 7        4              0.04                99.92             0.04
# 18      51              0.33                99.17             0.50
# 28    8954              0.02                99.04             0.94
# 10   10078              0.02                98.76             1.22
# 11    9661              0.09                98.66             1.25

# %% [markdown]
# # Which State/UTs has most active Cases ?

# %%
active= df.sort_values("Active", ascending= False)

# %%
active.head()
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 16          Kerala      3724030  175695     3529465   18870              4.72
# 20     Maharashtra      6401213   64790     6201168  135255              1.01
# 15       Karnataka      2931827   21507     2873281   37039              0.73
# 30      Tamil Nadu      2592436   20225     2537632   34579              0.78
# 1   Andhra Pradesh      1995669   16341     1965657   13671              0.82
#
#     Discharge Ratio (%)  Death Ratio (%)
# 16                94.78             0.51
# 20                96.87             2.11
# 15                98.00             1.26
# 30                97.89             1.33
# 1                 98.50             0.69

# %% [markdown]
# # Which State/UTs has minimum Death Ratio(%)

# %%
max_death_ratio= df.sort_values("Death Ratio (%)",ascending= False)

# %%
max_death_ratio.head()
# Out:
#       State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 27       Punjab       600008     543      583120   16345              0.09
# 34  Uttarakhand       342637     330      334934    7373              0.10
# 20  Maharashtra      6401213   64790     6201168  135255              1.01
# 24     Nagaland        29274    1088       27579     607              3.72
# 9           Goa       172683     884      168622    3177              0.51
#
#     Discharge Ratio (%)  Death Ratio (%)
# 27                97.19             2.72
# 34                97.75             2.15
# 20                96.87             2.11
# 24                94.21             2.07
# 9                 97.65             1.84

# %% [markdown]
# # Which State/UTs has minimum Death Ratio(%)

# %%
min_death_ratio= df.sort_values("Death Ratio (%)",ascending= True)

# %%
min_death_ratio.head()
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        10657       4       10649
# 23                                   Mizoram        49950    9084       40681
# 2                          Arunachal Pradesh        51655    1763       49640
# 18                               Lakshadweep        10295      34       10210
# 16                                    Kerala      3724030  175695     3529465
#
#     Deaths  Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 7        4              0.04                99.92             0.04
# 23     185             18.19                81.44             0.37
# 2      252              3.41                96.10             0.49
# 18      51              0.33                99.17             0.50
# 16   18870              4.72                94.78             0.51

# %% [markdown]
# # Which State has highest Discharged Patients??

# %%
max_discharge_patients= df.sort_values("Discharged", ascending= False)

# %%
max_discharge_patients.head()
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 20     Maharashtra      6401213   64790     6201168  135255              1.01
# 16          Kerala      3724030  175695     3529465   18870              4.72
# 15       Karnataka      2931827   21507     2873281   37039              0.73
# 30      Tamil Nadu      2592436   20225     2537632   34579              0.78
# 1   Andhra Pradesh      1995669   16341     1965657   13671              0.82
#
#     Discharge Ratio (%)  Death Ratio (%)
# 20                96.87             2.11
# 16                94.78             0.51
# 15                98.00             1.26
# 30                97.89             1.33
# 1                 98.50             0.69

# %% [markdown]
# # Which State has highest Total Cases ??

# %%
max_total_cases= df.sort_values("Total Cases",ascending= False)

# %%
max_total_cases.head()
# Out:
#          State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 20     Maharashtra      6401213   64790     6201168  135255              1.01
# 16          Kerala      3724030  175695     3529465   18870              4.72
# 15       Karnataka      2931827   21507     2873281   37039              0.73
# 30      Tamil Nadu      2592436   20225     2537632   34579              0.78
# 1   Andhra Pradesh      1995669   16341     1965657   13671              0.82
#
#     Discharge Ratio (%)  Death Ratio (%)
# 20                96.87             2.11
# 16                94.78             0.51
# 15                98.00             1.26
# 30                97.89             1.33
# 1                 98.50             0.69

# %% [markdown]
# # Which State/UTs has highest Active Ratio ??

# %%
highest_active_ratio= df.sort_values("Active Ratio (%)", ascending= False)

# %%
highest_active_ratio.head()
# Out:
#     State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 23    Mizoram        49950    9084       40681     185             18.19
# 29     Sikkim        28830    1982       26485     363              6.87
# 21    Manipur       108948    5721      101505    1722              5.25
# 22  Meghalaya        72412    3591       67581    1240              4.96
# 16     Kerala      3724030  175695     3529465   18870              4.72
#
#     Discharge Ratio (%)  Death Ratio (%)
# 23                81.44             0.37
# 29                91.87             1.26
# 21                93.17             1.58
# 22                93.33             1.71
# 16                94.78             0.51

# %%
max_deaths= df.sort_values("Deaths", ascending= False)

# %%
max_deaths.head()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 20    Maharashtra      6401213   64790     6201168  135255              1.01
# 15      Karnataka      2931827   21507     2873281   37039              0.73
# 30     Tamil Nadu      2592436   20225     2537632   34579              0.78
# 8           Delhi      1437156     471     1411612   25073              0.03
# 33  Uttar Pradesh      1708991     420     1685785   22786              0.02
#
#     Discharge Ratio (%)  Death Ratio (%)
# 20                96.87             2.11
# 15                98.00             1.26
# 30                97.89             1.33
# 8                 98.22             1.74
# 33                98.64             1.33

# %% [markdown]
# # Data Visulization

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Active",
             color= "green")
plt.tick_params(axis= "x", which= "major", labelsize= 15, rotation= 90)
plt.tick_params(axis= "y", which= "major", labelsize= 15)

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation= 90)
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Total Cases",
             color= "red")
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Active Ratio (%)")
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Death Ratio (%)",
             color= "yellow")
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Discharge Ratio (%)",
             color= "purple")
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.xticks(rotation=90)
sns.pointplot(data=df,
             x= "State/UTs",
             y= "Discharged",
             color= "Blue")
plt.show()

# %%
df.corr()
# Out:
#                      Total Cases    Active  Discharged    Deaths  \
# Total Cases             1.000000  0.663181    0.999898  0.907023
# Active                  0.663181  1.000000    0.653333  0.393393
# Discharged              0.999898  0.653333    1.000000  0.908726
# Deaths                  0.907023  0.393393    0.908726  1.000000
# Active Ratio (%)       -0.115642  0.167718   -0.121017 -0.134799
# Discharge Ratio (%)     0.102671 -0.143148    0.107895  0.087475
# Death Ratio (%)         0.092273 -0.167600    0.094009  0.291043
#
#                      Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# Total Cases                 -0.115642             0.102671         0.092273
# Active                       0.167718            -0.143148        -0.167600
# Discharged                  -0.121017             0.107895         0.094009
# Deaths                      -0.134799             0.087475         0.291043
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot= True);

# %%
plt.figure(figsize= (20,12))
plt.xticks(rotation= 90)
sns.pointplot(data= df,
             x= "State/UTs",
             y= "Deaths",
             color= "Orange")
plt.show()
